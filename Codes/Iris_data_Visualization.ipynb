# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import metrics
from pandas.plotting import scatter_matrix
sns.set()

# %%
iris = pd.read_csv("D:/DATASETS/iris_4.csv")
iris.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
print(iris.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  150 non-null    float64
#  1   SepalWidthCm   150 non-null    float64
#  2   PetalLengthCm  150 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
#  4   Species        150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB
# None

# %%
print(iris.describe())
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count     150.000000    150.000000     150.000000    150.000000
# mean        5.843333      3.054000       3.758667      1.198667
# std         0.828066      0.433594       1.764420      0.763161
# min         4.300000      2.000000       1.000000      0.100000
# 25%         5.100000      2.800000       1.600000      0.300000
# 50%         5.800000      3.000000       4.350000      1.300000
# 75%         6.400000      3.300000       5.100000      1.800000
# max         7.900000      4.400000       6.900000      2.500000

# %%
print(iris[iris.duplicated()])
print("There are 3 duplicates, therefore we must check whether each species data set is balanced in no's or no")
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 34             4.9           3.1            1.5           0.1     Iris-setosa
# 37             4.9           3.1            1.5           0.1     Iris-setosa
# 142            5.8           2.7            5.1           1.9  Iris-virginica
# There are 3 duplicates, therefore we must check whether each species data set is balanced in no's or no

# %%
print("Checking whether dataset is balanced")
print(iris['Species'].value_counts())
# Out:
# Checking whether dataset is balanced
# Iris-versicolor    50
# Iris-virginica     50
# Iris-setosa        50
# Name: Species, dtype: int64

# %%
plt.title('Count of Species')
sns.countplot(iris['Species'])
# Out:
# c:\users\deva\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:title={'center':'Count of Species'}, xlabel='Species', ylabel='count'>

# %% [markdown]
# <h3>Uni-variate Analysis</h3>
# <b>Comparison between various species based on sepal length and width

# %%
plt.figure(figsize = (17,9))
plt.title('Comparison between various species based on sapel length and width')
sns.scatterplot(iris['SepalLengthCm'],iris['SepalWidthCm'],hue =iris['Species'],s=60)
# Out:
# c:\users\deva\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:title={'center':'Comparison between various species based on sapel length and width'}, xlabel='SepalLengthCm', ylabel='SepalWidthCm'>

# %% [markdown]
# <b>Comparison between various species based on petal length and width

# %%
plt.figure(figsize=(16,9))
plt.title('Comparison between various species based on petal lenght and width')
sns.scatterplot(iris['PetalLengthCm'], iris['PetalWidthCm'], hue = iris['Species'], s= 50)
# Out:
# c:\users\deva\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:title={'center':'Comparison between various species based on petal lenght and width'}, xlabel='PetalLengthCm', ylabel='PetalWidthCm'>

# %% [markdown]
# <h3> Bi-variate Analysis

# %%
sns.pairplot(iris,hue="Species")

# %% [markdown]
# <h3> Correlation Matrix

# %%
plt.figure(figsize=(10,11))
sns.heatmap(iris.corr(),annot=True)
plt.plot()
# Out:
# []

# %%
iris.groupby('Species').agg(['mean','median'])
# Out:
#                 SepalLengthCm        SepalWidthCm        PetalLengthCm         \
#                          mean median         mean median          mean median
# Species
# Iris-setosa             5.006    5.0        3.418    3.4         1.464   1.50
# Iris-versicolor         5.936    5.9        2.770    2.8         4.260   4.35
# Iris-virginica          6.588    6.5        2.974    3.0         5.552   5.55
#
#                 PetalWidthCm
#                         mean median
# Species
# Iris-setosa            0.244    0.2
# Iris-versicolor        1.326    1.3
# Iris-virginica         2.026    2.0

# %% [markdown]
# <h3> Histograms</h3>

# %%
iris.hist(edgecolor='black', linewidth=1.2)
# Out:
# array([[<AxesSubplot:title={'center':'SepalLengthCm'}>,
#         <AxesSubplot:title={'center':'SepalWidthCm'}>],
#        [<AxesSubplot:title={'center':'PetalLengthCm'}>,
#         <AxesSubplot:title={'center':'PetalWidthCm'}>]], dtype=object)

# %%
scatter_matrix(iris,figsize=(10,10))
plt.show()

# %%
sns.FacetGrid(iris, hue="Species", height=5).map(sns.histplot, "SepalLengthCm").add_legend()
sns.FacetGrid(iris, hue="Species", height=5).map(sns.histplot, "SepalWidthCm").add_legend()
sns.FacetGrid(iris, hue="Species", height=5).map(sns.histplot, "PetalLengthCm").add_legend()
sns.FacetGrid(iris, hue="Species", height=5).map(sns.histplot, "PetalWidthCm").add_legend()
plt.show()

# %% [markdown]
# <h3>Box and whisker plots</h3>
# <b>boxplot to see how the categorical feature “Species” is distributed with all other four input variables

# %%
fig, axes = plt.subplots(2, 2, figsize=(16,9))
sns.boxplot( y="PetalWidthCm", x= "Species", data=iris, orient='v' , ax=axes[0, 0])
sns.boxplot( y="PetalLengthCm", x= "Species", data=iris, orient='v' , ax=axes[0, 1])
sns.boxplot( y="SepalLengthCm", x= "Species", data=iris, orient='v' , ax=axes[1, 0])
sns.boxplot( y="SepalWidthCm", x= "Species", data=iris, orient='v' , ax=axes[1, 1])
plt.show()

# %%
iris.plot(kind='box', sharex=False, sharey=False)
# Out:
# <AxesSubplot:>

# %% [markdown]
# <h3>Violin Plot </h3>
# <b>The violin plot shows density of the length and width in the species. The thinner part denotes that there is less density whereas the fatter part conveys higher density

# %%
fig, axes = plt.subplots(2, 2, figsize=(16,10))
sns.violinplot( y="PetalLengthCm", x= "Species", data=iris, ax=axes[0, 0])
sns.violinplot( y="PetalWidthCm", x= "Species", data=iris, ax=axes[0, 1])
sns.violinplot( y="SepalLengthCm", x= "Species", data=iris, ax=axes[1, 0])
sns.violinplot( y="SepalWidthCm", x= "Species", data=iris, ax=axes[1, 1])
plt.show()
